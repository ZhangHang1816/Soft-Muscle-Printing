# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from numpy.linalg import norm
from sys import platform
from point_in_polygon import wn_PnPoly
from pathplanner import *
# %config InlineBackend.figure_format = 'retina'
# %matplotlib notebook

# %%
from muscle_printing import *
# As defined in muscle_printing:
# SKIN = 2
# MUSCLE  = 1
#
TOOL = { # ratio between extruders
    CONDUCTIVE:[0, 0.5, 0, 0.5],
    MUSCLE:[0.5, 0, 0,  0.5],
    SKIN:[0, 0.5, 0.5,  0]
}
D = 22.63
# d = 1.75 # gauge14
d = .99  # gauge18

gcode_para = { # G code parameters
    'D':D,
    'd':d,
    'applied_percentage':1,
    'TOOL':TOOL,
    'dump_location':[0, -200, 55],
    'feedrate_move':1000,
    'feedrate_quickmove':1800,
    'feedrate_extrude':(d**2) / (3.2**2),
    'total_volume_change':4000.0, # [mm^3]
    'max_reuse_volume':1500,
    }
###################################################################################################
gcode_para['feedrate_extrude']
# Out:
# 0.09571289062499998

# %%
# lines = np.array([[0,0],[10,0],[10,5],[5,5],[5,10],[10,10],[5,15],[2,12],[0,0]])
# # plot
# fig = plt.figure()
# ax = fig.add_subplot(111)
# for k in range(len(lines)-1):
#     ax.plot(lines[k:k+2,0],lines[k:k+2,1],color ='g')
# plt.axis('equal');plt.grid();plt.show()
# # print(np.array(y_list))

# %%
num_layers = 15
z_start = 4.65
l1=20
l3 = 30
l2=50
h1=10
h2=20

x = 0 # offset in x-direction
y = 0 # offset in y-direction
lines = np.array(
[[l1/2+x,h1/2+y],[l3/2+x,h2/2+y],[l2/2+x,h2/2+y],[l2/2+x,-h2/2+y],[l3/2+x,-h2/2+y],[l1/2+x,-h1/2+y],[-l1/2+x,-h1/2+y],[-l3/2+x,-h2/2+y],[-l2/2+x,-h2/2+y],[-l2/2+x,h2/2+y],
[-l3/2+x,h2/2+y],[-l1/2+x,h1/2+y],[l1/2+x,h1/2+y]]
)

#input
d = 0.99
angle = np.pi/3
plotting = True

# %%
xxx =polygon_path(lines,d, angle = -np.pi/4,plotting = True)
# Out:
# <img src="data:image/png;base64,..." width="640">
